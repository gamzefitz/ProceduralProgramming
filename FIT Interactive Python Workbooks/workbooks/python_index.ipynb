# %% [markdown]
# <div style="display: flex; justify-content: space-between; white-space: nowrap;">
#     <div style="text-align:left; display:inline;">
#         <img  src="res/ict_apprenticeship_one_colour.jpg" alt="ICT Apprenticeship Logo" height="75">
#     </div>
#     <div style="text-align:center;">
#         <h1>FIT Interactive Workbooks</h1>
#     </div>
#     <div style="text-align:right; display:inline;">
#         <img src="res/fit_logo_tech_talent_pipeline.png" alt="Fastrack into Information Technology (FIT) Logo" height="75">
#     </div>
# </div>

# %% [markdown]
# # Getting Started with Workbooks
#
# These Jupyter Notebooks are designed to provide an interactive and visual way to write and execute Python code.

# %% [markdown]
# ## Workbook Index
# - [Python Workbook - Getting Started](./python_how_to_getting_started.ipynb)
# - [Python Workbook - Conditional Statements](./python_how_to_conditional_statements.ipynb)
# - [Python Workbook - Collections](./python_how_to_collections.ipynb)
# - [Python Workbook - Iteration Statements](./python_how_to_iteration_statements.ipynb)
# - [Python Workbook - Functions](./python_how_to_functions.ipynb)
# - [Python Workbook - Errors](./python_how_to_errors.ipynb)

# %% [markdown]
# <div style="display: flex; justify-content: space-between; white-space: nowrap;">
# <div style="text-align: right;">
# <a href="./python_how_to_getting_started.ipynb" style="padding-right: 150px; vertical-align: middle;">Start with the First Workbook (Getting Started)<img src="./res/arrow_forward.png" style="vertical-align: middle;"/></a>
# </div>
# </div>
